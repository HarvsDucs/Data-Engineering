# %%
from serpapi import GoogleSearch

params = {
  "q": "best solar company in Florida",
  "location": "Florida, United States",
  "hl": "en",
  "gl": "us",
  "google_domain": "google.com",
  "api_key": "3a1e4893d2da0c2711d84bf3f4e56cc88a598a9e971e62bb331366252d2ae543"
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '65c4dc4c8cd878414ccda85b',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/b31a872a478c0cf2/65c4dc4c8cd878414ccda85b.json',
#   'created_at': '2024-02-08 13:51:08 UTC',
#   'processed_at': '2024-02-08 13:51:08 UTC',
#   'google_url': 'https://www.google.com/search?q=best+solar+company+in+Florida&oq=best+solar+company+in+Florida&uule=w+CAIQICIVRmxvcmlkYSxVbml0ZWQgU3RhdGVz&hl=en&gl=us&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/b31a872a478c0cf2/65c4dc4c8cd878414ccda85b.html',
#   'total_time_taken': 2.87},
#  'search_parameters': {'engine': 'google',
#   'q': 'best solar company in Florida',
#   'location_requested': 'Florida, United States',
#   'location_used': 'Florida,United States',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'gl': 'us',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'best solar company in Florida',
#   'total_results': 30500000,
# ...

# %%
print(results['local_results'])
# Out:
# {'places': [{'position': 1, 'rating': 5.0, 'reviews_original': '(2)', 'reviews': 2, 'links': {'directions': 'https://www.google.com/maps/dir//Florida+Best+Solar+Energy,+1801+SW+Santa+Barbara+Pl,+Cape+Coral,+FL+33991/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x88db411c1f2208cf:0xa95b2349e8a595d?sa=X&ved=2ahUKEwiemPPU8ZuEAxUIh-4BHfJVAYQQ48ADegQILRAA&hl=en&gl=us'}, 'title': 'Florida Best Solar Energy', 'type': 'Solar energy system service', 'phone': '(239) 203-1690', 'address': 'Cape Coral, FL', 'hours': 'Open ⋅ Closes 8 PM'}, {'position': 2, 'rating': 4.5, 'reviews_original': '(65)', 'reviews': 65, 'description': '"Very professional and really seem like they know what they\'re doing."', 'links': {'website': 'https://www.floridapowerservices.com/', 'directions': 'https://www.google.com/maps/dir//Florida+Power+Services+%22The+Solar+Power+Company%22,+503+E+Jackson+St,+Tampa,+FL+33602/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x88c2c48b6e206cff:0xf483a6c22817f52c?sa=X&ved=2ahUKEwiemPPU8ZuEAxUIh-4BHfJVAYQQ48AD
# ...

# %%
print(results['local_results']['places'][0]['title'])
print(results['local_results']['places'][1]['title'])
print(results['local_results']['places'][2]['title'])
# Out:
# Florida Best Solar Energy
# Florida Power Services "The Solar Power Company"
# Solar Bear LLC
